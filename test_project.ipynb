# %% [markdown]
# <a href="https://colab.research.google.com/github/Waliamohini/Transformers-/blob/main/test_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Walmart_Sales.csv")

data.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
plt.scatter( data.Temperature, data.Weekly_Sales, s = 1)
plt.show()

# %%
def loss_function(m, b, points):
  total_error = 0
  for i in range (len(points)):
    x = points.iloc[i].Temperature
    y = points.iloc[i].Weekly_Sales

    total_error += (y - (m*x + b))**2

  total_error = total_error / len(points)
  return total_error

# %%
def gradient_descent(m_now, b_now, points, l):
  m_gradient = 0
  b_gradient = 0
  n = len(points)
  for i in range (n):
    x = points.iloc[i].Temperature
    y = points.iloc[i].Weekly_Sales

    m_gradient += -(2/n)*x*(y - (m_now*x - b_now))
    b_gradient += -(2/n) * (y - (m_now*x + b_now))

  m = m_now - m_gradient*l
  b = b_now - b_gradient*l
  return m, b

# %%
m = 0
b = 0
l = 0.0001
epochs = 300

for i in range (epochs):
  if i % 50 == 0 :
    print(f" Epochs : {i}")

    m, b = gradient_descent(m, b, data, l)

plt.scatter(data.Temperature, data.Weekly_Sales, s = 1)
x_values = range(20, 100) # Or use np.arange(100) if numpy is preferred
y_values = [m * x + b for x in x_values]

plt.plot(x_values, y_values, color='black') # Added color for clarity
plt.show()
# Out:
#  Epochs : 0
#  Epochs : 50
#  Epochs : 100
#  Epochs : 150
#  Epochs : 200
#  Epochs : 250
